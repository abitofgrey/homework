# %%
name = "Greylen"
age = 19
grade = 100.0
is_student = True
favorite_color = "grey"

print(name)
print(age)
print(grade)
print(is_student)
print(favorite_color)
# Out:
# Greylen
# 19
# 100.0
# True
# grey

# %%
name: str = name
age: int = age
grade: float = grade
is_student: bool = is_student
favorite_color: str = favorite_color

name = name.upper()
print(name)
# Out:
# GREYLEN

# %%
print(type(age + grade))
# Out:
# <class 'float'>

# %%
person = {
    "name": name,
    "age": age,
    "grade": grade,
    "is_student": is_student,
    "favorite_color": favorite_color,
}

print(person)
# Out:
# {'name': 'GREYLEN', 'age': 19, 'grade': 100.0, 'is_student': True, 'favorite_color': 'grey'}

# %%
print(f"My name is {person["name"]}. I am {person["age"]} years old. My favorite color is {person["favorite_color"]}. I will get a {person["grade"]} in this class.")
# Out:
# My name is GREYLEN. I am 19 years old. My favorite color is grey. I will get a 100.0 in this class.
